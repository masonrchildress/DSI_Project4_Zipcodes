# %%
import pandas as pd
import numpy as np

# %%
b_tier = pd.read_csv('./bottom_tier.csv', encoding = "ISO-8859-1")
b_tier.head()
# Out:
#    RegionName      City State                             Metro  \
# 0       79936   El Paso    TX                           El Paso
# 1       77449      Katy    TX  Houston-The Woodlands-Sugar Land
# 2       77084   Houston    TX  Houston-The Woodlands-Sugar Land
# 3       10467  New York    NY       New York-Newark-Jersey City
# 4       60640   Chicago    IL          Chicago-Naperville-Elgin
#
#        CountyName  SizeRank   2010-01   2010-02   2010-03   2010-04    ...     \
# 0  El Paso County         1   88686.0   88950.0   89250.0   89250.0    ...
# 1   Harris County         2   94900.0   94000.0   94900.0   94900.0    ...
# 2   Harris County         3   89900.0   89900.0   93300.0   95000.0    ...
# 3    Bronx County         4       NaN       NaN       NaN       NaN    ...
# 4     Cook County         5  125000.0  125000.0  125500.0  127000.0    ...
#
#     2018-02   2018-03   2018-04   2018-05   2018-06   2018-07   2018-08  \
# ...

# %%
cols = ['RegionName', 'State', '2018-11']
b_tier = b_tier[cols]
b_tier.head()
# Out:
#    RegionName State   2018-11
# 0       79936    TX   96750.0
# 1       77449    TX  150000.0
# 2       77084    TX  149000.0
# 3       10467    NY  164500.0
# 4       60640    IL  134900.0

# %%
b_tier.columns = ['zip', 'state', '2018-11']

# %%
b_tier.head()
# Out:
#      zip state   2018-11
# 0  79936    TX   96750.0
# 1  77449    TX  150000.0
# 2  77084    TX  149000.0
# 3  10467    NY  164500.0
# 4  60640    IL  134900.0

# %%
b_tier.zip = b_tier.zip.map(lambda cell: str(cell))

# %%
b_tier.zip.dtypes
# Out:
# dtype('O')

# %%
b_tier.zip = b_tier.zip.map(lambda cell: '0' + cell if len(cell) < 5 else cell)

# %%
b_tier.drop(columns='zip_length', inplace = True)

# %%
b_tier.head()
# Out:
#      zip state   2018-11
# 0  79936    TX   96750.0
# 1  77449    TX  150000.0
# 2  77084    TX  149000.0
# 3  10467    NY  164500.0
# 4  60640    IL  134900.0

# %%
b_tier.to_csv('cleaned_b_tier.csv', encoding='utf-8', index=False)
